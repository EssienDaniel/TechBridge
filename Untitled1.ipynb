# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
recoveries = pd.read_csv("time_series_covid19_recovered_global.csv")
death = pd.read_csv("time_series_covid19_deaths_global.csv")
confirm = pd.read_csv("time_series_covid19_confirmed_global.csv")

# %%
recoveries_ng = recoveries[recoveries["Country/Region"] =="Nigeria"]
recoveries_ng

#plt.plot(death, )
# Out:
#     Province/State Country/Region    Lat    Long  1/22/20  1/23/20  1/24/20  \
# 181            NaN        Nigeria  9.082  8.6753        0        0        0
#
#      1/25/20  1/26/20  1/27/20  ...  9/30/20  10/1/20  10/2/20  10/3/20  \
# 181        0        0        0  ...    50358    50452    50593    50718
#
#      10/4/20  10/5/20  10/6/20  10/7/20  10/8/20  10/9/20
# 181    50768    50951    51308    51403    51551    51614
#
# [1 rows x 266 columns]

# %%
recoveries_case = recoveries_ng.iloc[:,4:]
plt.plot(recoveries_ng.columns[4:],recoveries_ng.iloc[0][4:])
#plt.xticks()

# %%
recoveries_ca = recoveries[recoveries["Country/Region"] =="Canada"]
recoveries_ca

# %%
recoveries_case = recoveries_ca.iloc[:,4:]
plt.plot(recoveries_ca.columns[4:],recoveries_ca.iloc[0][4:]);

# %%
recoveries_ja = recoveries[recoveries["Country/Region"] =="Japan"]
recoveries_ja
# Out:
#     Province/State Country/Region        Lat        Long  1/22/20  1/23/20  \
# 138            NaN          Japan  36.204824  138.252924        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  9/30/20  10/1/20  10/2/20  \
# 138        0        0        1        1  ...    75522    76081    76700
#
#      10/3/20  10/4/20  10/5/20  10/6/20  10/7/20  10/8/20  10/9/20
# 138    76700    77851    78071    78521    79123    79674    80140
#
# [1 rows x 266 columns]

# %%
recoveries_case_ja = recoveries_ja.iloc[:,4:]
plt.plot(recoveries_ja.columns[4:],recoveries_ja.iloc[0][4:]);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
plt.figure(figsize=(10,6))
plt.plot(recoveries_ng.columns[4:],recoveries_ng.iloc[0][4:], label = "Nigeria")
plt.plot(recoveries_ja.columns[4:],recoveries_ja.iloc[0][4:], label="Japan")
plt.plot(recoveries_ca.columns[4:],recoveries_ca.iloc[0][4:], label="Canada")
plt.legend()
plt.title("Plot showing rate of recoveries")
plt.xticks(rotation=90);

# %%
sns.lmplot(recoveries_ca.columns[4:], data=recoveries_ca.iloc[0][4:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-98bdecd8b7b7> in <module>
# ----> 1 sns.lmplot(recoveries_ca.columns[4:], data=recoveries_ca.iloc[0][4:])
#
# TypeError: lmplot() missing 1 required positional argument: 'y'

# %%
recoveries_ja = recoveries[recoveries["Country/Region"] =="Japan"]
ca_values = recoveries_ja.iloc[0][4:].astype("int")
ca_date_numeric = list(range(len(recoveries_ja.columns[4:])))


df = pd.DataFrame({"Date":ca_date_numeric, "values":ca_values}).reset_index()

# %%
plt.figure(figsize=(12,5))
sns.regplot("Date","values", data=df, fit_reg=True, order=3);
